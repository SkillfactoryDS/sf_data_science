# %% [markdown]
# # Вариаты оформления
# ## gkjgi
# ### kgkhg
# #### upoiu
# `score_game(random_predict) #вызов функции
# print (hello)`
#
# * qwe
# * erfw
# * dfrg
# 1. sdf
# 2.
# <b>;bhj</b>
#
# <i>xfghdj</i>
#
# *sgfhsou*
#
# **lkjdl**
#
# ***ldrghlo***
#
# ~~dfghsdg~~
#
# [url text](https://youtube.com)
#
# ![img](d:\Учеба\car\bmw.png)
# ### <center> формулы на LaTeX</center>
#
# $$c=\sqrt{4}$$

# %%
import numpy

# %%
numpy.arange? #Вазов справки

# %% [markdown]
# ### Магические команды
# #### Список по [ссылке](https://ipython.org/ipython-doc/3/interactive/magics.html)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot([1, 3, 6], [1, 2, 5])

# %%
# %time
import time
time.sleep
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# <function time.sleep>
